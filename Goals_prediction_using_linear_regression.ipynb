# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:/PYTHON/Football teams.csv")
df.head()
# Out:
#                   Team      Tournament  Goals  Shots pg  yellow_cards  \
# 0      Manchester City  Premier League     83      15.8            46
# 1        Bayern Munich      Bundesliga     99      17.1            44
# 2  Paris Saint-Germain         Ligue 1     86      15.0            73
# 3            Barcelona          LaLiga     85      15.3            68
# 4          Real Madrid          LaLiga     67      14.4            57
#
#    red_cards  Possession%  Pass%  AerialsWon  Rating
# 0          2         60.8   89.4        12.8    7.01
# 1          3         58.1   85.5        12.9    6.95
# 2          7         60.1   89.5         9.5    6.88
# 3          2         62.4   89.7        10.6    6.87
# 4          2         57.7   87.7        11.8    6.86

# %%
df.groupby('Tournament')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Team          98 non-null     object
#  1   Tournament    98 non-null     object
#  2   Goals         98 non-null     int64
#  3   Shots pg      98 non-null     float64
#  4   yellow_cards  98 non-null     int64
#  5   red_cards     98 non-null     int64
#  6   Possession%   98 non-null     float64
#  7   Pass%         98 non-null     float64
#  8   AerialsWon    98 non-null     float64
#  9   Rating        98 non-null     float64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 7.8+ KB

# %%
df.dropna(inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#            Goals   Shots pg  yellow_cards  red_cards  Possession%      Pass%  \
# count  98.000000  98.000000     98.000000  98.000000    98.000000  98.000000
# mean   52.183673  11.851020     69.704082   3.336735    49.995918  80.441837
# std    16.445691   2.149718     15.137316   2.148814     4.890068   4.690172
# min    20.000000   7.100000     40.000000   0.000000    38.500000  66.500000
# 25%    40.250000  10.325000     60.000000   2.000000    46.225000  78.025000
# 50%    50.000000  11.450000     67.500000   3.000000    49.750000  80.800000
# 75%    61.750000  13.350000     80.000000   4.750000    52.850000  83.450000
# max    99.000000  17.100000    117.000000  10.000000    62.400000  89.700000
#
#        AerialsWon     Rating
# count   98.000000  98.000000
# mean    16.006122   6.646122
# std      3.078955   0.132148
# min      9.500000   6.410000
# 25%     14.025000   6.540000
# 50%     16.100000   6.630000
# 75%     17.850000   6.730000
# max     26.800000   7.010000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
sns.pairplot(df,hue='Tournament')

# %%
df_by_league = df.groupby("Tournament")

# %%
df_by_league.describe()
# Out:
#                Goals                                                        \
#                count       mean        std   min    25%   50%    75%   max
# Tournament
# Bundesliga      18.0  51.555556  18.573296  25.0  36.75  52.0  60.75  99.0
# LaLiga          20.0  47.650000  14.872352  28.0  35.50  46.5  56.00  85.0
# Ligue 1         20.0  52.450000  14.897810  25.0  42.00  50.0  56.25  86.0
# Premier League  20.0  51.200000  16.728796  20.0  39.00  51.0  63.50  83.0
# Serie A         20.0  58.000000  17.041744  39.0  44.50  51.5  69.50  90.0
#
#                Shots pg             ... AerialsWon       Rating            \
#                   count       mean  ...        75%   max  count      mean
# Tournament                          ...
# Bundesliga         18.0  12.372222  ...     18.200  22.2   18.0  6.652222
# LaLiga             20.0  10.660000  ...     18.350  26.8   20.0  6.597500
# Ligue 1            20.0  11.700000  ...     17.025  18.6   20.0  6.638500
# ...

# %%
list(df_by_league)[0]
# Out:
# ('Bundesliga',
#                     Team  Tournament  Goals  Shots pg  yellow_cards  red_cards  \
#  1         Bayern Munich  Bundesliga     99      17.1            44          3
#  8     Borussia Dortmund  Bundesliga     75      14.6            43          1
#  18            Wolfsburg  Bundesliga     61      14.1            56          3
#  21           RB Leipzig  Bundesliga     60      16.0            57          0
#  25     Bayer Leverkusen  Bundesliga     53      13.0            58          0
#  26  Eintracht Frankfurt  Bundesliga     69      13.2            80          1
#  30  Borussia M.Gladbach  Bundesliga     64      13.4            61          2
#  33        VfB Stuttgart  Bundesliga     56      13.4            63          2
#  49           Hoffenheim  Bundesliga     52      12.6            65          4
#  54         Union Berlin  Bundesliga     50      11.7            55          2
#  57             Freiburg  Bundesliga     52      11.4            63          0
# ...

# %%
df_by_league.head()
# Out:
#                    Team      Tournament  Goals  Shots pg  yellow_cards  \
# 0       Manchester City  Premier League     83      15.8            46
# 1         Bayern Munich      Bundesliga     99      17.1            44
# 2   Paris Saint-Germain         Ligue 1     86      15.0            73
# 3             Barcelona          LaLiga     85      15.3            68
# 4           Real Madrid          LaLiga     67      14.4            57
# 5     Manchester United  Premier League     73      13.8            64
# 6              Juventus         Serie A     77      15.7            76
# 7           Aston Villa  Premier League     55      13.7            63
# 8     Borussia Dortmund      Bundesliga     75      14.6            43
# 9       Atletico Madrid          LaLiga     67      12.1           100
# 10             Atalanta         Serie A     90      16.3            66
# 11              Chelsea  Premier League     58      14.6            49
# ...

# %%
type(df_by_league)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df1 = list(df_by_league)[0]
df1
# Out:
# ('Bundesliga',
#                     Team  Tournament  Goals  Shots pg  yellow_cards  red_cards  \
#  1         Bayern Munich  Bundesliga     99      17.1            44          3
#  8     Borussia Dortmund  Bundesliga     75      14.6            43          1
#  18            Wolfsburg  Bundesliga     61      14.1            56          3
#  21           RB Leipzig  Bundesliga     60      16.0            57          0
#  25     Bayer Leverkusen  Bundesliga     53      13.0            58          0
#  26  Eintracht Frankfurt  Bundesliga     69      13.2            80          1
#  30  Borussia M.Gladbach  Bundesliga     64      13.4            61          2
#  33        VfB Stuttgart  Bundesliga     56      13.4            63          2
#  49           Hoffenheim  Bundesliga     52      12.6            65          4
#  54         Union Berlin  Bundesliga     50      11.7            55          2
#  57             Freiburg  Bundesliga     52      11.4            63          0
# ...

# %%
type(df1)
# Out:
# tuple

# %%
print(df_by_league.index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-51d3f8e01fd3> in <module>
# ----> 1 print(df_by_league.index)
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'index'

# %%
corr_mat = df.corr()

# %%
plt.subplots(figsize=(12,9))
sns.heatmap(corr_mat,vmax=1,square = True)
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#                   Team      Tournament  Goals  Shots pg  yellow_cards  \
# 0      Manchester City  Premier League     83      15.8            46
# 1        Bayern Munich      Bundesliga     99      17.1            44
# 2  Paris Saint-Germain         Ligue 1     86      15.0            73
# 3            Barcelona          LaLiga     85      15.3            68
# 4          Real Madrid          LaLiga     67      14.4            57
#
#    red_cards  Possession%  Pass%  AerialsWon  Rating
# 0          2         60.8   89.4        12.8    7.01
# 1          3         58.1   85.5        12.9    6.95
# 2          7         60.1   89.5         9.5    6.88
# 3          2         62.4   89.7        10.6    6.87
# 4          2         57.7   87.7        11.8    6.86

# %%
co = df.corr()

# %%
print(co)
# Out:
#                  Goals  Shots pg  yellow_cards  red_cards  Possession%  \
# Goals         1.000000  0.829698     -0.189157  -0.001185     0.717834
# Shots pg      0.829698  1.000000     -0.369343  -0.105080     0.759153
# yellow_cards -0.189157 -0.369343      1.000000   0.368847    -0.164302
# red_cards    -0.001185 -0.105080      0.368847   1.000000    -0.083360
# Possession%   0.717834  0.759153     -0.164302  -0.083360     1.000000
# Pass%         0.694214  0.684035     -0.184238  -0.043761     0.851458
# AerialsWon   -0.495579 -0.382147      0.060116  -0.031791    -0.543970
# Rating        0.852152  0.851265     -0.417049  -0.162358     0.734978
#
#                  Pass%  AerialsWon    Rating
# Goals         0.694214   -0.495579  0.852152
# Shots pg      0.684035   -0.382147  0.851265
# yellow_cards -0.184238    0.060116 -0.417049
# red_cards    -0.043761   -0.031791 -0.162358
# Possession%   0.851458   -0.543970  0.734978
# Pass%         1.000000   -0.764788  0.668573
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98 entries, 0 to 97
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Team          98 non-null     object
#  1   Tournament    98 non-null     object
#  2   Goals         98 non-null     int64
#  3   Shots pg      98 non-null     float64
#  4   yellow_cards  98 non-null     int64
#  5   red_cards     98 non-null     int64
#  6   Possession%   98 non-null     float64
#  7   Pass%         98 non-null     float64
#  8   AerialsWon    98 non-null     float64
#  9   Rating        98 non-null     float64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 8.4+ KB

# %%
x = df[['Shots pg','Possession%','Pass%','Rating']]
y = df['Goals']
print(x.shape)
y.shape
# Out:
# (98, 4)
# (98,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3,random_state = 100)
print(x_train.shape)
print(x_test.shape)
# Out:
# (68, 4)
# (30, 4)

# %%
import statsmodels.api as sm

# %%
model = sm.OLS(y_train,x_train).fit()

# %%
print(model.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Goals   R-squared (uncentered):                   0.971
# Model:                            OLS   Adj. R-squared (uncentered):              0.969
# Method:                 Least Squares   F-statistic:                              527.5
# Date:                Sat, 24 Jul 2021   Prob (F-statistic):                    3.25e-48
# Time:                        23:12:33   Log-Likelihood:                         -248.08
# No. Observations:                  68   AIC:                                      504.2
# Df Residuals:                      64   BIC:                                      513.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
pred = model.predict(x_test)

# %%
data = list(zip(y_test,pred))
comtab = pd.DataFrame(data,columns=['Actual','Predicted'])
comtab.head()
# Out:
#    Actual  Predicted
# 0      39  46.629256
# 1      47  35.640353
# 2      69  60.304159
# 3      53  61.859969
# 4      50  52.540984

# %%
print(x_test,y_test)
# Out:
#     Shots pg  Possession%  Pass%  Rating
# 88      10.4         48.4   82.5    6.49
# 75       9.0         46.1   79.7    6.54
# 26      13.2         52.4   79.6    6.73
# 29      12.1         58.7   86.2    6.70
# 43      11.8         49.4   81.3    6.64
# 83      10.6         47.1   77.3    6.51
# 35      13.9         58.2   87.8    6.67
# 90       9.4         43.4   70.0    6.47
# 22      13.7         55.1   80.8    6.77
# 63      11.6         49.0   79.3    6.59
# 5       13.8         54.5   84.8    6.85
# 32      13.5         56.8   85.6    6.69
# 11      14.6         58.6   87.0    6.83
# 82       8.9         41.0   72.2    6.51
# 28      14.3         51.5   84.5    6.71
# 80       9.8         46.8   81.0    6.52
# 36      11.5         46.9   79.8    6.66
# 76       9.8         44.1   74.6    6.53
# 85      10.1         51.5   80.1    6.50
# 84       9.1         44.6   72.9    6.50
# 20      16.1         53.6   84.7    6.80
# 23      12.3         44.5   77.8    6.77
# ...

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(y_test,pred))
print(rmse)
# Out:
# 8.90695544001993

# %%
ans = model.predict([[11.6,49.1,79.3,6.59]])

# %%
print(ans)
# Out:
# [50.97565072]

# %% [markdown]
# As the adjusted R square value is 0.971 so our model is working perfectly
